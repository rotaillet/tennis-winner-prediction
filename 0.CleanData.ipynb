# %% [markdown]
# # Clean Data

# %% [markdown]
# **INPUT**: NO INPUT
#
# **OUTPUT**: "./data/0cleanDataset.csv"

# %% [markdown]
# This notebook will clean and randomize the data extracted from https://github.com/JeffSackmann/tennis_atp into something we can work with. Importantly, I want to minize data leakage (since last time it was a big concern).

# %% [markdown]
# ## Merge Data and Basic Clean

# %% [markdown]
# First of all, we need some libraries.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %% [markdown]
# Let's first visualize the data a bit.

# %%
df = pd.read_csv("./data/all/atp_matches_2022.csv")
df.head(100)
# Out:
#    tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0   2022-8888      Atp Cup    Hard         16             A      20220103
# 1   2022-8888      Atp Cup    Hard         16             A      20220103
# 2   2022-8888      Atp Cup    Hard         16             A      20220103
# 3   2022-8888      Atp Cup    Hard         16             A      20220103
# 4   2022-8888      Atp Cup    Hard         16             A      20220103
# ..        ...          ...     ...        ...           ...           ...
# 95  2022-9665    Melbourne    Hard         32             A      20220103
# 96  2022-9665    Melbourne    Hard         32             A      20220103
# 97  2022-9665    Melbourne    Hard         32             A      20220103
# 98  2022-9665    Melbourne    Hard         32             A      20220103
# 99  2022-9665    Melbourne    Hard         32             A      20220103
#
#     match_num  winner_id  winner_seed winner_entry            winner_name  \
# 0         300     200000          NaN          NaN  Felix Auger Aliassime
# 1         299     133430          NaN          NaN       Denis Shapovalov
# 2         298     105138          NaN          NaN  Roberto Bautista Agut
# 3         297     105807          NaN          NaN    Pablo Carreno Busta
# 4         296     106421          NaN          NaN        Daniil Medvedev
# ..        ...        ...          ...          ...                    ...
# 95        286     202195          NaN            Q          Maxime Cressy
# 96        284     105575          NaN            Q      Ricardas Berankis
# 97        283     200615          NaN          NaN         Alexei Popyrin
# 98        282     134868          NaN          NaN      Tallon Griekspoor
# 99        280     144684          NaN          NaN            Alex Molcan
#
#    winner_hand  winner_ht winner_ioc  winner_age  loser_id  loser_seed  \
# 0            R      193.0        CAN        21.4    105138         NaN
# 1            L      185.0        CAN        22.7    105807         NaN
# 2            R      183.0        ESP        33.7    128034         NaN
# 3            R      188.0        ESP        30.4    126591         NaN
# 4            R      198.0        RUS        25.8    200000         NaN
# ..         ...        ...        ...         ...       ...         ...
# 95           R      201.0        USA        24.6    124187         2.0
# 96           R      175.0        LTU        31.5    106218         NaN
# 97           R      196.0        AUS        22.4    105882         NaN
# 98           R      188.0        NED        25.5    136440         7.0
# 99           L      178.0        SVK        24.0    104312         NaN
#
#    loser_entry             loser_name loser_hand  loser_ht loser_ioc  \
# 0          NaN  Roberto Bautista Agut          R     183.0       ESP
# 1          NaN    Pablo Carreno Busta          R     188.0       ESP
# 2          NaN         Hubert Hurkacz          R     196.0       POL
# 3          NaN          Jan Zielinski          R     180.0       POL
# 4          NaN  Felix Auger Aliassime          R     193.0       CAN
# ..         ...                    ...        ...       ...       ...
# 95         NaN          Reilly Opelka          R     211.0       USA
# 96         NaN           Marcos Giron          R     180.0       USA
# 97         NaN      Stefano Travaglia          R     185.0       ITA
# 98         NaN        Dominik Koepfer          L     180.0       GER
# 99           Q          Andreas Seppi          R     190.0       ITA
#
#     loser_age              score  best_of round  minutes  w_ace  w_df  w_svpt  \
# 0        33.7         7-6(3) 6-3        3     F    129.0   15.0   6.0    78.0
# 1        30.4            6-4 6-3        3     F     98.0    7.0   2.0    78.0
# 2        24.8  7-6(6) 2-6 7-6(5)        3    SF    164.0    1.0   2.0    96.0
# 3        25.1            6-2 6-1        3    SF     53.0    6.0   0.0    45.0
# 4        21.4            6-4 6-0        3    SF     68.0    6.0   4.0    41.0
# ..        ...                ...      ...   ...      ...    ...   ...     ...
# 95       24.3  4-6 7-6(5) 7-6(9)        3   R16    161.0   17.0  10.0   125.0
# 96       28.4            7-5 6-4        3   R32     90.0    1.0   1.0    67.0
# 97       30.0         7-6(5) 6-3        3   R32    103.0   11.0   5.0    79.0
# 98       27.6            6-3 6-4        3   R32     84.0    4.0   2.0    73.0
# 99       37.8     6-4 6-7(6) 6-3        3   R32    150.0    5.0   3.0    88.0
#
#     w_1stIn  w_1stWon  w_2ndWon  w_SvGms  w_bpSaved  w_bpFaced  l_ace  l_df  \
# 0      51.0      38.0      14.0     11.0       10.0       11.0    0.0   2.0
# 1      49.0      34.0      16.0     10.0        8.0        9.0    1.0   0.0
# 2      64.0      50.0      20.0     16.0        1.0        4.0   24.0   3.0
# 3      33.0      25.0       8.0      8.0        0.0        0.0    2.0   1.0
# 4      25.0      22.0      10.0      8.0        0.0        0.0    6.0   2.0
# ..      ...       ...       ...      ...        ...        ...    ...   ...
# 95     85.0      68.0      20.0     17.0        9.0       10.0   29.0   4.0
# 96     41.0      31.0      13.0     11.0        2.0        4.0    5.0   1.0
# 97     46.0      35.0      16.0     10.0        5.0        6.0    1.0   3.0
# 98     38.0      30.0      16.0     10.0        7.0        8.0    1.0   1.0
# 99     54.0      39.0      21.0     16.0        3.0        6.0    7.0   1.0
#
#     l_svpt  l_1stIn  l_1stWon  l_2ndWon  l_SvGms  l_bpSaved  l_bpFaced  \
# 0     70.0     50.0      32.0       7.0     10.0        3.0        5.0
# 1     50.0     33.0      21.0       8.0      9.0        3.0        6.0
# 2    120.0     80.0      62.0      20.0     16.0        6.0        7.0
# 3     38.0     27.0      17.0       1.0      7.0        4.0        8.0
# 4     48.0     35.0      22.0       4.0      8.0        3.0        7.0
# ..     ...      ...       ...       ...      ...        ...        ...
# 95   106.0     69.0      59.0      24.0     17.0        2.0        2.0
# 96    54.0     29.0      24.0      10.0     11.0        0.0        4.0
# 97    77.0     42.0      28.0      18.0     11.0        4.0        7.0
# 98    53.0     36.0      25.0       8.0      9.0        3.0        6.0
# 99   110.0     65.0      43.0      22.0     15.0        9.0       14.0
#
#     winner_rank  winner_rank_points  loser_rank  loser_rank_points
# 0          11.0              3308.0        19.0             2260.0
# 1          14.0              2475.0        20.0             2230.0
# 2          19.0              2260.0         9.0             3706.0
# 3          20.0              2230.0       860.0               18.0
# 4           2.0              8640.0        11.0             3308.0
# ..          ...                 ...         ...                ...
# 95        112.0               683.0        26.0             1936.0
# 96        104.0               739.0        66.0              929.0
# 97         61.0              1000.0        78.0              846.0
# 98         65.0               966.0        54.0             1101.0
# 99         88.0               806.0       102.0              744.0
#
# [100 rows x 49 columns]

# %% [markdown]
# Let's concat all the files into one dataframe so it's easier to work with.

# %%
all_data = pd.read_csv("./data/all/atp_matches_1991.csv")

for year in range(1992, 2025):
    file = "./data/all/atp_matches_"+str(year)+".csv"
    
    year_data = pd.read_csv(file)

    all_data = pd.concat([all_data, year_data], axis=0)

all_data
# Out:
#                             tourney_id                  tourney_name surface  \
# 0                             1991-339                      Adelaide    Hard
# 1                             1991-339                      Adelaide    Hard
# 2                             1991-339                      Adelaide    Hard
# 3                             1991-339                      Adelaide    Hard
# 4                             1991-339                      Adelaide    Hard
# ...                                ...                           ...     ...
# 3071  2024-M-DC-2024-WG2-PO-URU-MDA-01  Davis Cup WG2 PO: URU vs MDA    Clay
# 3072  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
# 3073  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
# 3074  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
# 3075  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
#
#       draw_size tourney_level  tourney_date  match_num  winner_id  \
# 0            32             A      19901231          1     101723
# 1            32             A      19901231          2     100946
# 2            32             A      19901231          3     101234
# 3            32             A      19901231          4     101889
# 4            32             A      19901231          5     101274
# ...         ...           ...           ...        ...        ...
# 3071          4             D      20240203          5     212051
# 3072          4             D      20240202          1     122533
# 3073          4             D      20240202          2     144748
# 3074          4             D      20240202          4     122533
# 3075          4             D      20240202          5     202475
#
#       winner_seed winner_entry                winner_name winner_hand  \
# 0             NaN          NaN             Magnus Larsson           R
# 1             NaN            Q       Slobodan Zivojinovic           R
# 2             NaN          NaN              Patrik Kuhnen           R
# 3             8.0          NaN            Todd Woodbridge           R
# 4             NaN          NaN              Udo Riglewski           R
# ...           ...          ...                        ...         ...
# 3071          NaN          NaN  Joaquin  Aguilar Cardozo            U
# 3072          NaN          NaN               Nam Hoang Ly           R
# 3073          NaN          NaN               Kris Van Wyk           R
# 3074          NaN          NaN               Nam Hoang Ly           R
# 3075          NaN          NaN             Philip Henning           R
#
#       winner_ht winner_ioc  winner_age  loser_id  loser_seed loser_entry  \
# 0         193.0        SWE        20.7    101414         1.0         NaN
# 1         198.0        YUG        27.4    101256         NaN         NaN
# 2         190.0        GER        24.8    101421         NaN         NaN
# 3         178.0        AUS        19.7    101703         NaN         NaN
# 4         185.0        GER        24.4    101843         4.0         NaN
# ...         ...        ...         ...       ...         ...         ...
# 3071        NaN        URU        18.8    209943         NaN         NaN
# 3072      175.0        VIE        26.9    202475         NaN         NaN
# 3073      185.0        RSA        27.3    144775         NaN         NaN
# 3074      175.0        VIE        26.9    144748         NaN         NaN
# 3075        NaN        RSA        23.2    144775         NaN         NaN
#
#             loser_name loser_hand  loser_ht loser_ioc  loser_age  \
# 0         Boris Becker          R     190.0       GER       23.1
# 1       Mark Kratzmann          L     178.0       AUS       24.6
# 2       Veli Paloheimo          R     183.0       FIN       23.0
# 3      Guillaume Raoux          R     180.0       FRA       20.8
# 4       Sergi Bruguera          R     188.0       ESP       19.9
# ...                ...        ...       ...       ...        ...
# 3071      Ilya Snitari          R     188.0       MDA       21.8
# 3072    Philip Henning          R       NaN       RSA       23.2
# 3073  Linh Giang Trinh          R     183.0       VIE       26.4
# 3074      Kris Van Wyk          R     185.0       RSA       27.3
# 3075  Linh Giang Trinh          R     183.0       VIE       26.4
#
#                score  best_of round  minutes  w_ace  w_df  w_svpt  w_1stIn  \
# 0     6-4 3-6 7-6(2)        3   R32    130.0    6.0   2.0    96.0     55.0
# 1     6-3 3-6 7-6(6)        3   R32    119.0   19.0   4.0   101.0     56.0
# 2            6-0 6-4        3   R32     71.0    6.0   1.0    54.0     31.0
# 3         7-6(2) 6-1        3   R32     85.0    2.0   0.0    60.0     40.0
# 4            7-5 6-3        3   R32     90.0    4.0   2.0    72.0     40.0
# ...              ...      ...   ...      ...    ...   ...     ...      ...
# 3071         6-1 6-0        3    RR     77.0    0.0   0.0    36.0     22.0
# 3072         6-3 6-4        3    RR    131.0    1.0   1.0    86.0     60.0
# 3073     4-6 6-3 4-0        3    RR    131.0    4.0   2.0    76.0     46.0
# 3074     6-4 3-6 6-3        3    RR    159.0    0.0   1.0    84.0     61.0
# 3075         6-2 6-2        3    RR    101.0    1.0   0.0    47.0     28.0
#
#       w_1stWon  w_2ndWon  w_SvGms  w_bpSaved  w_bpFaced  l_ace  l_df  l_svpt  \
# 0         39.0      25.0     15.0        2.0        4.0    8.0   3.0    95.0
# 1         45.0      25.0     15.0        9.0       10.0    8.0   2.0    84.0
# 2         24.0      13.0      8.0        1.0        1.0    2.0   2.0    60.0
# 3         30.0      14.0      9.0        3.0        3.0    3.0   3.0    74.0
# 4         33.0      14.0     10.0        7.0        8.0    2.0   2.0    77.0
# ...        ...       ...      ...        ...        ...    ...   ...     ...
# 3071      15.0      10.0      7.0        1.0        1.0    1.0   1.0    61.0
# 3072      40.0      13.0     10.0        8.0        9.0    2.0   1.0    56.0
# 3073      32.0      10.0     12.0        6.0       11.0    0.0   2.0    71.0
# 3074      41.0      13.0     14.0        2.0        5.0    5.0   3.0    86.0
# 3075      21.0      11.0      8.0        0.0        1.0    0.0   0.0    71.0
#
#       l_1stIn  l_1stWon  l_2ndWon  l_SvGms  l_bpSaved  l_bpFaced  winner_rank  \
# 0        62.0      44.0      23.0     16.0        6.0        8.0         56.0
# 1        41.0      35.0      27.0     15.0        1.0        2.0        304.0
# 2        37.0      22.0       6.0      8.0        4.0        8.0         82.0
# 3        45.0      30.0      11.0     10.0        5.0        8.0         50.0
# 4        41.0      28.0      15.0     11.0        4.0        8.0         88.0
# ...       ...       ...       ...      ...        ...        ...          ...
# 3071     30.0      17.0       7.0      6.0        8.0       14.0       1109.0
# 3072     41.0      25.0       6.0      9.0        1.0        4.0        554.0
# 3073     51.0      25.0       7.0     11.0        5.0       12.0        416.0
# 3074     51.0      32.0      17.0     14.0        5.0        9.0        554.0
# 3075     53.0      25.0       8.0      8.0        9.0       14.0        748.0
#
#       winner_rank_points  loser_rank  loser_rank_points
# 0                    NaN         2.0                NaN
# 1                    NaN        75.0                NaN
# 2                    NaN        69.0                NaN
# 3                    NaN        84.0                NaN
# 4                    NaN        28.0                NaN
# ...                  ...         ...                ...
# 3071                 8.0       740.0               34.0
# 3072                67.0       748.0               32.0
# 3073               109.0         NaN                NaN
# 3074                67.0       416.0              109.0
# 3075                32.0         NaN                NaN
#
# [108375 rows x 49 columns]

# %% [markdown]
# As you can see, we have a lot of NaN data. We need to get rid of some that data, since it's not really useful.

# %% [markdown]
# Let's drop all those rows with NaN values:

# %%
all_data_filtered = all_data.dropna(subset=[
    'winner_id', 'loser_id', 'winner_ht', 'loser_ht', 'winner_age', 'loser_age',
    "w_ace", "w_df", "w_svpt", "w_1stIn", "w_1stWon", "w_2ndWon", "w_SvGms", "w_bpSaved", "w_bpFaced",
    "l_ace", "l_df", "l_svpt", "l_1stIn", "l_1stWon", "l_2ndWon", "l_SvGms", "l_bpSaved", "l_bpFaced",
    'winner_rank_points', 'loser_rank_points', 'winner_rank', 'loser_rank', "surface"
    ]
)
all_data_filtered = all_data_filtered.reset_index(drop=True)
all_data_filtered
# Out:
#                              tourney_id                  tourney_name surface  \
# 0                              1991-301                      Auckland    Hard
# 1                              1991-301                      Auckland    Hard
# 2                              1991-301                      Auckland    Hard
# 3                              1991-301                      Auckland    Hard
# 4                              1991-301                      Auckland    Hard
# ...                                 ...                           ...     ...
# 95370  2024-M-DC-2024-WG2-PO-TOG-INA-01  Davis Cup WG2 PO: TOG vs INA    Hard
# 95371  2024-M-DC-2024-WG2-PO-TUN-CRC-01  Davis Cup WG2 PO: TUN vs CRC    Hard
# 95372  2024-M-DC-2024-WG2-PO-URU-MDA-01  Davis Cup WG2 PO: URU vs MDA    Clay
# 95373  2024-M-DC-2024-WG2-PO-URU-MDA-01  Davis Cup WG2 PO: URU vs MDA    Clay
# 95374  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
#
#        draw_size tourney_level  tourney_date  match_num  winner_id  \
# 0             32             A      19910107          1     101142
# 1             32             A      19910107          2     101613
# 2             32             A      19910107          3     101179
# 3             32             A      19910107          4     101117
# 4             32             A      19910107          5     101901
# ...          ...           ...           ...        ...        ...
# 95370          4             D      20240203          4     207134
# 95371          4             D      20240202          1     121411
# 95372          4             D      20240203          1     208364
# 95373          4             D      20240203          4     105430
# 95374          4             D      20240202          4     122533
#
#        winner_seed winner_entry             winner_name winner_hand  \
# 0              1.0          NaN          Emilio Sanchez           R
# 1              NaN            Q      Malivai Washington           R
# 2              NaN          NaN  Jean Philippe Fleurian           R
# 3              NaN          NaN              Eric Jelen           R
# 4              NaN            Q             Chuck Adams           R
# ...            ...          ...                     ...         ...
# 95370          NaN          NaN        Fitriadi M Rifqi           R
# 95371          NaN          NaN           Moez Echargui           R
# 95372          NaN          NaN       Franco Roncadelli           L
# 95373          NaN          NaN              Radu Albot           R
# 95374          NaN          NaN            Nam Hoang Ly           R
#
#        winner_ht winner_ioc  winner_age  loser_id  loser_seed loser_entry  \
# 0          180.0        ESP        25.6    101746         NaN         NaN
# 1          180.0        USA        21.5    100587         NaN          WC
# 2          185.0        FRA        25.3    101601         NaN          WC
# 3          180.0        GER        25.8    101332         8.0         NaN
# 4          185.0        USA        19.7    101735         3.0         NaN
# ...          ...        ...         ...       ...         ...         ...
# 95370      175.0        INA        25.0    133933         NaN         NaN
# 95371      178.0        TUN        31.0    132374         NaN         NaN
# 95372      185.0        URU        23.9    209943         NaN         NaN
# 95373      175.0        MDA        34.2    208364         NaN         NaN
# 95374      175.0        VIE        26.9    144748         NaN         NaN
#
#                      loser_name loser_hand  loser_ht loser_ioc  loser_age  \
# 0                  Renzo Furlan          R     175.0       ITA       20.6
# 1                     Steve Guy          R     188.0       NZL       31.8
# 2                  Brett Steven          R     185.0       NZL       21.6
# 3                   Gilad Bloom          L     173.0       ISR       23.8
# 4              Richard Fromberg          R     196.0       AUS       20.6
# ...                         ...        ...       ...       ...        ...
# 95370  Thomas Yaka Kofi Setodji          R     183.0       TOG       28.2
# 95371              Jesse Flores          R     188.0       CRC       28.8
# 95372              Ilya Snitari          R     188.0       MDA       21.8
# 95373         Franco Roncadelli          L     185.0       URU       23.9
# 95374              Kris Van Wyk          R     185.0       RSA       27.3
#
#              score  best_of round  minutes  w_ace  w_df  w_svpt  w_1stIn  \
# 0          6-4 6-1        3   R32     63.0    1.0   0.0    53.0     37.0
# 1          6-3 6-2        3   R32     72.0    5.0   1.0    56.0     25.0
# 2      2-6 6-1 6-2        3   R32    101.0    2.0   4.0    80.0     55.0
# 3      6-3 1-6 6-4        3   R32    108.0    0.0   1.0    82.0     55.0
# 4          6-3 6-4        3   R32     65.0    4.0   4.0    65.0     46.0
# ...            ...      ...   ...      ...    ...   ...     ...      ...
# 95370      6-2 6-3        3    RR     87.0    1.0   2.0    52.0     32.0
# 95371      6-2 6-3        3    RR     65.0    4.0   2.0    56.0     35.0
# 95372  4-6 6-1 6-1        3    RR    137.0    1.0   2.0    74.0     50.0
# 95373      6-3 6-1        3    RR     95.0    2.0   1.0    50.0     30.0
# 95374  6-4 3-6 6-3        3    RR    159.0    0.0   1.0    84.0     61.0
#
#        w_1stWon  w_2ndWon  w_SvGms  w_bpSaved  w_bpFaced  l_ace  l_df  l_svpt  \
# 0          30.0       7.0      9.0        5.0        6.0    3.0   0.0    46.0
# 1          17.0      20.0      9.0        1.0        2.0    4.0   7.0    56.0
# 2          35.0      16.0     12.0        2.0        4.0    1.0   3.0    68.0
# 3          35.0      14.0     13.0        6.0       10.0    3.0   2.0    96.0
# 4          34.0      12.0     10.0        2.0        2.0    1.0   3.0    49.0
# ...         ...       ...      ...        ...        ...    ...   ...     ...
# 95370      25.0      11.0      9.0        2.0        3.0    2.0   1.0    50.0
# 95371      30.0      11.0      9.0        4.0        4.0    3.0   2.0    49.0
# 95372      31.0      13.0     12.0        5.0        9.0    0.0   5.0    92.0
# 95373      19.0      14.0      8.0        3.0        4.0    1.0   1.0    82.0
# 95374      41.0      13.0     14.0        2.0        5.0    5.0   3.0    86.0
#
#        l_1stIn  l_1stWon  l_2ndWon  l_SvGms  l_bpSaved  l_bpFaced  \
# 0         30.0      17.0       7.0      8.0        2.0        6.0
# 1         30.0      22.0       6.0      8.0        7.0       11.0
# 2         43.0      24.0      14.0     11.0        4.0        8.0
# 3         61.0      38.0      15.0     13.0        8.0       12.0
# 4         25.0      21.0      12.0      9.0        4.0        6.0
# ...        ...       ...       ...      ...        ...        ...
# 95370     35.0      19.0       5.0      8.0        5.0        9.0
# 95371     30.0      17.0       9.0      8.0        2.0        5.0
# 95372     52.0      24.0      18.0     12.0        8.0       16.0
# 95373     66.0      33.0       6.0      8.0        6.0       11.0
# 95374     51.0      32.0      17.0     14.0        5.0        9.0
#
#        winner_rank  winner_rank_points  loser_rank  loser_rank_points
# 0              9.0              1487.0        78.0              459.0
# 1             94.0               371.0       220.0              114.0
# 2             77.0               468.0       212.0              116.0
# 3             65.0               502.0        72.0              483.0
# 4            190.0               142.0        28.0              876.0
# ...            ...                 ...         ...                ...
# 95370        569.0                64.0       819.0               24.0
# 95371        279.0               205.0       900.0               18.0
# 95372        616.0                55.0       740.0               34.0
# 95373        136.0               489.0       616.0               55.0
# 95374        554.0                67.0       416.0              109.0
#
# [95375 rows x 49 columns]

# %% [markdown]
# Removing NaN values from the columns of interest did not remove that much data. We end up with a lot of data still, so this should be okay.

# %% [markdown]
# ## Randomize Winner and Loser

# %% [markdown]
# The current dataset has labels like winner and loser. We want to randomize this and assign a Player 1 and Player 2. My first try at this project I did not do this. I think it's totally possible to not have any data leakage, and randomize it just before training (as I did in DataAnalysis.ipynb). However, there's less risk if we randomize from the beginning. So, let's do that.

# %% [markdown]
# These are the columns we should be switching:

# %%
columnsWinner = [
    "winner_id","winner_seed", "winner_entry", "winner_name", "winner_hand", "winner_ht", "winner_ioc", "winner_age", "w_ace", "w_df", "w_svpt", "w_1stIn", "w_1stWon", "w_2ndWon", "w_SvGms", "w_bpSaved", "w_bpFaced", "winner_rank","winner_rank_points"
]
columnsLoser = [
    "loser_id","loser_seed", "loser_entry", "loser_name", "loser_hand", "loser_ht", "loser_ioc", "loser_age", "l_ace", "l_df", "l_svpt", "l_1stIn", "l_1stWon", "l_2ndWon", "l_SvGms", "l_bpSaved", "l_bpFaced", "loser_rank","loser_rank_points"
]

# %% [markdown]
# Let's first rename them to Player 1 and Player 2.

# %%
# Creating a rename mapping
rename_dict = {col: col.replace("winner", "p1").replace("w_", "p1_") for col in columnsWinner}
rename_dict.update({col: col.replace("loser", "p2").replace("l_", "p2_") for col in columnsLoser})

# Renaming columns
all_data_filtered = all_data_filtered.rename(columns=rename_dict)
all_data_filtered
# Out:
#                              tourney_id                  tourney_name surface  \
# 0                              1991-301                      Auckland    Hard
# 1                              1991-301                      Auckland    Hard
# 2                              1991-301                      Auckland    Hard
# 3                              1991-301                      Auckland    Hard
# 4                              1991-301                      Auckland    Hard
# ...                                 ...                           ...     ...
# 95370  2024-M-DC-2024-WG2-PO-TOG-INA-01  Davis Cup WG2 PO: TOG vs INA    Hard
# 95371  2024-M-DC-2024-WG2-PO-TUN-CRC-01  Davis Cup WG2 PO: TUN vs CRC    Hard
# 95372  2024-M-DC-2024-WG2-PO-URU-MDA-01  Davis Cup WG2 PO: URU vs MDA    Clay
# 95373  2024-M-DC-2024-WG2-PO-URU-MDA-01  Davis Cup WG2 PO: URU vs MDA    Clay
# 95374  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
#
#        draw_size tourney_level  tourney_date  match_num   p1_id  p1_seed  \
# 0             32             A      19910107          1  101142      1.0
# 1             32             A      19910107          2  101613      NaN
# 2             32             A      19910107          3  101179      NaN
# 3             32             A      19910107          4  101117      NaN
# 4             32             A      19910107          5  101901      NaN
# ...          ...           ...           ...        ...     ...      ...
# 95370          4             D      20240203          4  207134      NaN
# 95371          4             D      20240202          1  121411      NaN
# 95372          4             D      20240203          1  208364      NaN
# 95373          4             D      20240203          4  105430      NaN
# 95374          4             D      20240202          4  122533      NaN
#
#       p1_entry                 p1_name p1_hand  p1_ht p1_ioc  p1_age   p2_id  \
# 0          NaN          Emilio Sanchez       R  180.0    ESP    25.6  101746
# 1            Q      Malivai Washington       R  180.0    USA    21.5  100587
# 2          NaN  Jean Philippe Fleurian       R  185.0    FRA    25.3  101601
# 3          NaN              Eric Jelen       R  180.0    GER    25.8  101332
# 4            Q             Chuck Adams       R  185.0    USA    19.7  101735
# ...        ...                     ...     ...    ...    ...     ...     ...
# 95370      NaN        Fitriadi M Rifqi       R  175.0    INA    25.0  133933
# 95371      NaN           Moez Echargui       R  178.0    TUN    31.0  132374
# 95372      NaN       Franco Roncadelli       L  185.0    URU    23.9  209943
# 95373      NaN              Radu Albot       R  175.0    MDA    34.2  208364
# 95374      NaN            Nam Hoang Ly       R  175.0    VIE    26.9  144748
#
#        p2_seed p2_entry                   p2_name p2_hand  p2_ht p2_ioc  \
# 0          NaN      NaN              Renzo Furlan       R  175.0    ITA
# 1          NaN       WC                 Steve Guy       R  188.0    NZL
# 2          NaN       WC              Brett Steven       R  185.0    NZL
# 3          8.0      NaN               Gilad Bloom       L  173.0    ISR
# 4          3.0      NaN          Richard Fromberg       R  196.0    AUS
# ...        ...      ...                       ...     ...    ...    ...
# 95370      NaN      NaN  Thomas Yaka Kofi Setodji       R  183.0    TOG
# 95371      NaN      NaN              Jesse Flores       R  188.0    CRC
# 95372      NaN      NaN              Ilya Snitari       R  188.0    MDA
# 95373      NaN      NaN         Franco Roncadelli       L  185.0    URU
# 95374      NaN      NaN              Kris Van Wyk       R  185.0    RSA
#
#        p2_age        score  best_of round  minutes  p1_ace  p1_df  p1_svpt  \
# 0        20.6      6-4 6-1        3   R32     63.0     1.0    0.0     53.0
# 1        31.8      6-3 6-2        3   R32     72.0     5.0    1.0     56.0
# 2        21.6  2-6 6-1 6-2        3   R32    101.0     2.0    4.0     80.0
# 3        23.8  6-3 1-6 6-4        3   R32    108.0     0.0    1.0     82.0
# 4        20.6      6-3 6-4        3   R32     65.0     4.0    4.0     65.0
# ...       ...          ...      ...   ...      ...     ...    ...      ...
# 95370    28.2      6-2 6-3        3    RR     87.0     1.0    2.0     52.0
# 95371    28.8      6-2 6-3        3    RR     65.0     4.0    2.0     56.0
# 95372    21.8  4-6 6-1 6-1        3    RR    137.0     1.0    2.0     74.0
# 95373    23.9      6-3 6-1        3    RR     95.0     2.0    1.0     50.0
# 95374    27.3  6-4 3-6 6-3        3    RR    159.0     0.0    1.0     84.0
#
#        p1_1stIn  p1_1stWon  p1_2ndWon  p1_SvGms  p1_bpSaved  p1_bpFaced  \
# 0          37.0       30.0        7.0       9.0         5.0         6.0
# 1          25.0       17.0       20.0       9.0         1.0         2.0
# 2          55.0       35.0       16.0      12.0         2.0         4.0
# 3          55.0       35.0       14.0      13.0         6.0        10.0
# 4          46.0       34.0       12.0      10.0         2.0         2.0
# ...         ...        ...        ...       ...         ...         ...
# 95370      32.0       25.0       11.0       9.0         2.0         3.0
# 95371      35.0       30.0       11.0       9.0         4.0         4.0
# 95372      50.0       31.0       13.0      12.0         5.0         9.0
# 95373      30.0       19.0       14.0       8.0         3.0         4.0
# 95374      61.0       41.0       13.0      14.0         2.0         5.0
#
#        p2_ace  p2_df  p2_svpt  p2_1stIn  p2_1stWon  p2_2ndWon  p2_SvGms  \
# 0         3.0    0.0     46.0      30.0       17.0        7.0       8.0
# 1         4.0    7.0     56.0      30.0       22.0        6.0       8.0
# 2         1.0    3.0     68.0      43.0       24.0       14.0      11.0
# 3         3.0    2.0     96.0      61.0       38.0       15.0      13.0
# 4         1.0    3.0     49.0      25.0       21.0       12.0       9.0
# ...       ...    ...      ...       ...        ...        ...       ...
# 95370     2.0    1.0     50.0      35.0       19.0        5.0       8.0
# 95371     3.0    2.0     49.0      30.0       17.0        9.0       8.0
# 95372     0.0    5.0     92.0      52.0       24.0       18.0      12.0
# 95373     1.0    1.0     82.0      66.0       33.0        6.0       8.0
# 95374     5.0    3.0     86.0      51.0       32.0       17.0      14.0
#
#        p2_bpSaved  p2_bpFaced  p1_rank  p1_rank_points  p2_rank  \
# 0             2.0         6.0      9.0          1487.0     78.0
# 1             7.0        11.0     94.0           371.0    220.0
# 2             4.0         8.0     77.0           468.0    212.0
# 3             8.0        12.0     65.0           502.0     72.0
# 4             4.0         6.0    190.0           142.0     28.0
# ...           ...         ...      ...             ...      ...
# 95370         5.0         9.0    569.0            64.0    819.0
# 95371         2.0         5.0    279.0           205.0    900.0
# 95372         8.0        16.0    616.0            55.0    740.0
# 95373         6.0        11.0    136.0           489.0    616.0
# 95374         5.0         9.0    554.0            67.0    416.0
#
#        p2_rank_points
# 0               459.0
# 1               114.0
# 2               116.0
# 3               483.0
# 4               876.0
# ...               ...
# 95370            24.0
# 95371            18.0
# 95372            34.0
# 95373            55.0
# 95374           109.0
#
# [95375 rows x 49 columns]

# %% [markdown]
# However, all the winners are now in P1. We don't want that, we want to switch them around 50% of the time.

# %%
# Generate a boolean mask for 50% of the rows (True means swap)
mask = np.random.rand(len(all_data_filtered)) < 0.5 

# Identify the player 1 and player 2 columns
player1_cols = [col for col in all_data_filtered.columns if "player1" in col or "p1_" in col]
player2_cols = [col for col in all_data_filtered.columns if "player2" in col or "p2_" in col]

# Create the RESULT column (1 = not swapped, 0 = swapped)
all_data_filtered["RESULT"] = np.where(mask, 0, 1)

# Swap values where mask is True
all_data_filtered.loc[mask, player1_cols], all_data_filtered.loc[mask, player2_cols] = all_data_filtered.loc[mask, player2_cols].values, all_data_filtered.loc[mask, player1_cols].values

# %%
all_data_filtered
# Out:
#                              tourney_id                  tourney_name surface  \
# 0                              1991-301                      Auckland    Hard
# 1                              1991-301                      Auckland    Hard
# 2                              1991-301                      Auckland    Hard
# 3                              1991-301                      Auckland    Hard
# 4                              1991-301                      Auckland    Hard
# ...                                 ...                           ...     ...
# 95370  2024-M-DC-2024-WG2-PO-TOG-INA-01  Davis Cup WG2 PO: TOG vs INA    Hard
# 95371  2024-M-DC-2024-WG2-PO-TUN-CRC-01  Davis Cup WG2 PO: TUN vs CRC    Hard
# 95372  2024-M-DC-2024-WG2-PO-URU-MDA-01  Davis Cup WG2 PO: URU vs MDA    Clay
# 95373  2024-M-DC-2024-WG2-PO-URU-MDA-01  Davis Cup WG2 PO: URU vs MDA    Clay
# 95374  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
#
#        draw_size tourney_level  tourney_date  match_num   p1_id  p1_seed  \
# 0             32             A      19910107          1  101142      1.0
# 1             32             A      19910107          2  101613      NaN
# 2             32             A      19910107          3  101601      NaN
# 3             32             A      19910107          4  101117      NaN
# 4             32             A      19910107          5  101901      NaN
# ...          ...           ...           ...        ...     ...      ...
# 95370          4             D      20240203          4  133933      NaN
# 95371          4             D      20240202          1  132374      NaN
# 95372          4             D      20240203          1  208364      NaN
# 95373          4             D      20240203          4  208364      NaN
# 95374          4             D      20240202          4  144748      NaN
#
#       p1_entry                   p1_name p1_hand  p1_ht p1_ioc  p1_age  \
# 0          NaN            Emilio Sanchez       R  180.0    ESP    25.6
# 1            Q        Malivai Washington       R  180.0    USA    21.5
# 2           WC              Brett Steven       R  185.0    NZL    21.6
# 3          NaN                Eric Jelen       R  180.0    GER    25.8
# 4            Q               Chuck Adams       R  185.0    USA    19.7
# ...        ...                       ...     ...    ...    ...     ...
# 95370      NaN  Thomas Yaka Kofi Setodji       R  183.0    TOG    28.2
# 95371      NaN              Jesse Flores       R  188.0    CRC    28.8
# 95372      NaN         Franco Roncadelli       L  185.0    URU    23.9
# 95373      NaN         Franco Roncadelli       L  185.0    URU    23.9
# 95374      NaN              Kris Van Wyk       R  185.0    RSA    27.3
#
#         p2_id  p2_seed p2_entry                 p2_name p2_hand  p2_ht p2_ioc  \
# 0      101746      NaN      NaN            Renzo Furlan       R  175.0    ITA
# 1      100587      NaN       WC               Steve Guy       R  188.0    NZL
# 2      101179      NaN      NaN  Jean Philippe Fleurian       R  185.0    FRA
# 3      101332      8.0      NaN             Gilad Bloom       L  173.0    ISR
# 4      101735      3.0      NaN        Richard Fromberg       R  196.0    AUS
# ...       ...      ...      ...                     ...     ...    ...    ...
# 95370  207134      NaN      NaN        Fitriadi M Rifqi       R  175.0    INA
# 95371  121411      NaN      NaN           Moez Echargui       R  178.0    TUN
# 95372  209943      NaN      NaN            Ilya Snitari       R  188.0    MDA
# 95373  105430      NaN      NaN              Radu Albot       R  175.0    MDA
# 95374  122533      NaN      NaN            Nam Hoang Ly       R  175.0    VIE
#
#        p2_age        score  best_of round  minutes  p1_ace  p1_df  p1_svpt  \
# 0        20.6      6-4 6-1        3   R32     63.0     1.0    0.0     53.0
# 1        31.8      6-3 6-2        3   R32     72.0     5.0    1.0     56.0
# 2        25.3  2-6 6-1 6-2        3   R32    101.0     1.0    3.0     68.0
# 3        23.8  6-3 1-6 6-4        3   R32    108.0     0.0    1.0     82.0
# 4        20.6      6-3 6-4        3   R32     65.0     4.0    4.0     65.0
# ...       ...          ...      ...   ...      ...     ...    ...      ...
# 95370    25.0      6-2 6-3        3    RR     87.0     2.0    1.0     50.0
# 95371    31.0      6-2 6-3        3    RR     65.0     3.0    2.0     49.0
# 95372    21.8  4-6 6-1 6-1        3    RR    137.0     1.0    2.0     74.0
# 95373    34.2      6-3 6-1        3    RR     95.0     1.0    1.0     82.0
# 95374    26.9  6-4 3-6 6-3        3    RR    159.0     5.0    3.0     86.0
#
#        p1_1stIn  p1_1stWon  p1_2ndWon  p1_SvGms  p1_bpSaved  p1_bpFaced  \
# 0          37.0       30.0        7.0       9.0         5.0         6.0
# 1          25.0       17.0       20.0       9.0         1.0         2.0
# 2          43.0       24.0       14.0      11.0         4.0         8.0
# 3          55.0       35.0       14.0      13.0         6.0        10.0
# 4          46.0       34.0       12.0      10.0         2.0         2.0
# ...         ...        ...        ...       ...         ...         ...
# 95370      35.0       19.0        5.0       8.0         5.0         9.0
# 95371      30.0       17.0        9.0       8.0         2.0         5.0
# 95372      50.0       31.0       13.0      12.0         5.0         9.0
# 95373      66.0       33.0        6.0       8.0         6.0        11.0
# 95374      51.0       32.0       17.0      14.0         5.0         9.0
#
#        p2_ace  p2_df  p2_svpt  p2_1stIn  p2_1stWon  p2_2ndWon  p2_SvGms  \
# 0         3.0    0.0     46.0      30.0       17.0        7.0       8.0
# 1         4.0    7.0     56.0      30.0       22.0        6.0       8.0
# 2         2.0    4.0     80.0      55.0       35.0       16.0      12.0
# 3         3.0    2.0     96.0      61.0       38.0       15.0      13.0
# 4         1.0    3.0     49.0      25.0       21.0       12.0       9.0
# ...       ...    ...      ...       ...        ...        ...       ...
# 95370     1.0    2.0     52.0      32.0       25.0       11.0       9.0
# 95371     4.0    2.0     56.0      35.0       30.0       11.0       9.0
# 95372     0.0    5.0     92.0      52.0       24.0       18.0      12.0
# 95373     2.0    1.0     50.0      30.0       19.0       14.0       8.0
# 95374     0.0    1.0     84.0      61.0       41.0       13.0      14.0
#
#        p2_bpSaved  p2_bpFaced  p1_rank  p1_rank_points  p2_rank  \
# 0             2.0         6.0      9.0          1487.0     78.0
# 1             7.0        11.0     94.0           371.0    220.0
# 2             2.0         4.0    212.0           116.0     77.0
# 3             8.0        12.0     65.0           502.0     72.0
# 4             4.0         6.0    190.0           142.0     28.0
# ...           ...         ...      ...             ...      ...
# 95370         2.0         3.0    819.0            24.0    569.0
# 95371         4.0         4.0    900.0            18.0    279.0
# 95372         8.0        16.0    616.0            55.0    740.0
# 95373         3.0         4.0    616.0            55.0    136.0
# 95374         2.0         5.0    416.0           109.0    554.0
#
#        p2_rank_points  RESULT
# 0               459.0       1
# 1               114.0       1
# 2               468.0       0
# 3               483.0       1
# 4               876.0       1
# ...               ...     ...
# 95370            64.0       0
# 95371           205.0       0
# 95372            34.0       1
# 95373           489.0       0
# 95374            67.0       0
#
# [95375 rows x 50 columns]

# %% [markdown]
# And volià! Now we have a clean dataset with Player 1 and Player 2 randomized.

# %% [markdown]
# **RESULT 1 - Means that Player 1 WON**
#
# **RESULT 0 - Means that Player 2 WON**

# %% [markdown]
# Let's export this to "./data/0cleanDataset.csv"

# %%
all_data_filtered.to_csv("./data/0cleanDataset.csv", index=False)
